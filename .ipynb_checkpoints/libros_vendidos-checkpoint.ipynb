# %%
# %matplotlib inline

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.set(style='ticks', palette='Set2')
# Out:
# /Users/mmngreco/Virtualenvs/ipynb/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
url = 'http://www.federacioneditores.org/SectorEdit/DatosEstadisticos.asp'
data = pd.read_html('http://www.federacioneditores.org/SectorEdit/DatosEstadisticos.asp', skiprows=16, header=0, index_col=0)[0]

# %%
data
# Out:
#                                                        Año 2005     Año 2006  \
# Número de agentes editoriales privados                    2.781        2.673
# Número de agentes editoriales públicos                      615          563
# Porcentaje de la producción editorial de instit...        11,5%        12,3%
# ISBN concedidos                                          76.265       77.330
# Títulos vivos en catálogo                               325.808      346.706
# Títulos editados en edición de bolsillo                   5.378        5.232
# Ejemplares editados                                 321.469.155  338.086.000
# Ejemplares vendidos                                 230.626.086  228.220.878
# Porcentaje de títulos que son traducciones de o...        25,8%       28,02%
# Valor de las ventas de libros en el mercado int...      2.93320      3.01454
# Valor de las exportaciones de libros (miles de ...      452.894      557.052
# Tirada media de ejemplares por título (número d...        4.619        4.905
# Precio medio del libro (euros)                             1272         1321
# Distribución por materias de la cifra global de...          NaN          NaN
# Literatura                                                21,4%        21,1%
# Texto no universitario                                    23,8%        24,4%
# Científico/técnico                                         6,5%         5,4%
# Infantil y juvenil                                         9,6%        10,7%
# Divulgación general                                        7,2%         8,2%
# Diccionarios/enciclopedias                                 7,6%         5,4%
# Ciencias Sociales y Humanidades                           10,5%        12,1%
# Libros prácticos                                           6,1%         6,4%
# Comics                                                     3,4%         2,8%
# Otros                                                      3,8%         3,4%
# NaN                                                         NaN          NaN
# NaN                                                         NaN          NaN
#
#                                                        Año 2007     Año 2008  \
# Número de agentes editoriales privados                    2.803        2.892
# Número de agentes editoriales públicos                      597          580
# Porcentaje de la producción editorial de instit...        11,2%         9,8%
# ISBN concedidos                                          82.559      104.223
# Títulos vivos en catálogo                               369.588      393.012
# Títulos editados en edición de bolsillo                   6.392        6.608
# Ejemplares editados                                 357.560.000  367.460.000
# Ejemplares vendidos                                 250.860.500  240.660.000
# Porcentaje de títulos que son traducciones de o...        24,7%        24,8%
# Valor de las ventas de libros en el mercado int...      3.12317      3.18550
# Valor de las exportaciones de libros (miles de ...      554.934      545.982
# Tirada media de ejemplares por título (número d...        5.475        5.035
# Precio medio del libro (euros)                             1175         1326
# Distribución por materias de la cifra global de...          NaN          NaN
# Literatura                                                21,2%        21,7%
# Texto no universitario                                    25,7%        28,2%
# Científico/técnico                                         5,6%         5,0%
# Infantil y juvenil                                        10,6%        10,3%
# Divulgación general                                          9%         8,2%
# Diccionarios/enciclopedias                                 4,8%         4,6%
# Ciencias Sociales y Humanidades                           11,4%        11,9%
# Libros prácticos                                           5,9%         5,3%
# Comics                                                     2,5%         2,7%
# Otros                                                      3,3%         2,2%
# NaN                                                         NaN          NaN
# NaN                                                         NaN          NaN
#
#                                                        Año 2009     Año 2010  \
# Número de agentes editoriales privados                    3.032        2.994
# Número de agentes editoriales públicos                      532          529
# Porcentaje de la producción editorial de instit...         8,6%         8,0%
# ISBN concedidos                                         110.205      114.205
# Títulos vivos en catálogo                               414.727      439.991
# Títulos editados en edición de bolsillo                   6.425        6.001
# Ejemplares editados                                 329.830.000  302.631.000
# Ejemplares vendidos                                 236.197.000  228.230.000
# Porcentaje de títulos que son traducciones de o...        22,9%        22,1%
# Valor de las ventas de libros en el mercado int...      3.10958      2.89080
# Valor de las exportaciones de libros (miles de ...      442.367      457.792
# Tirada media de ejemplares por título (número d...        4.328        3.790
# Precio medio del libro (euros)                             1317         1267
# Distribución por materias de la cifra global de...          NaN          NaN
# Literatura                                                22,9%        22,3%
# Texto no universitario                                    27,2%        28,3%
# Científico/técnico                                         5,0%         5,3%
# Infantil y juvenil                                        11,3%        12,1%
# Divulgación general                                        8,8%         8,3%
# Diccionarios/enciclopedias                                 3,7%         3,0%
# Ciencias Sociales y Humanidades                           11,0%        11,5%
# Libros prácticos                                           5,2%         4,4%
# Comics                                                     2,6%         2,9%
# Otros                                                      2,4%         1,8%
# NaN                                                         NaN          NaN
# NaN                                                         NaN          NaN
#
#                                                        Año 2011     Año 2012  \
# Número de agentes editoriales privados                    2.988        2.835
# Número de agentes editoriales públicos                      476          352
# Porcentaje de la producción editorial de instit...         7,0%         7,5%
# ISBN concedidos                                         111.907      104.724
# Títulos vivos en catálogo                               464.981      490.752
# Títulos editados en edición de bolsillo                   5.376        4.806
# Ejemplares editados                                 286.462.000  280.251.000
# Ejemplares vendidos                                 199.814.000  170.237.000
# Porcentaje de títulos que son traducciones de o...        21,1%        22,0%
# Valor de las ventas de libros en el mercado int...      2.77234      2.47149
# Valor de las exportaciones de libros (miles de ...      506.537      527.343
# Tirada media de ejemplares por título (número d...        3.441        3.540
# Precio medio del libro (euros)                             1387         1452
# Distribución por materias de la cifra global de...          NaN          NaN
# Literatura                                                19,9%        22,9%
# Texto no universitario                                    31,3%        32,5%
# Científico/técnico                                         4,8%         3,7%
# Infantil y juvenil                                        12,2%        12,0%
# Divulgación general                                        7,7%         6,6%
# Diccionarios/enciclopedias                                 2,3%         1,8%
# Ciencias Sociales y Humanidades                           11,4%        10,9%
# Libros prácticos                                           5,4%         5,7%
# Comics                                                     3,4%         2,2%
# Otros                                                      1,6%         1,7%
# NaN                                                         NaN          NaN
# NaN                                                         NaN          NaN
#
#                                                        Año 2013  Unnamed: 10  \
# Número de agentes editoriales privados                    2.750          NaN
# Número de agentes editoriales públicos                      336          NaN
# Porcentaje de la producción editorial de instit...           9%          NaN
# ISBN concedidos                                          89.130          NaN
# Títulos vivos en catálogo                               524.213          NaN
# Títulos editados en edición de bolsillo                   4.099          NaN
# Ejemplares editados                                 246.345.000          NaN
# Ejemplares vendidos                                 153.830.000          NaN
# Porcentaje de títulos que son traducciones de o...        22,3%          NaN
# Valor de las ventas de libros en el mercado int...      2.18197          NaN
# Valor de las exportaciones de libros (miles de ...      526.482          NaN
# Tirada media de ejemplares por título (número d...        3.223          NaN
# Precio medio del libro (euros)                             1418          NaN
# Distribución por materias de la cifra global de...          NaN          NaN
# Literatura                                                21,5%          NaN
# Texto no universitario                                    33,3%          NaN
# Científico/técnico                                         3,2%          NaN
# Infantil y juvenil                                        12,2%          NaN
# Divulgación general                                        6,8%          NaN
# Diccionarios/enciclopedias                                 2,1%          NaN
# Ciencias Sociales y Humanidades                           10,6%          NaN
# Libros prácticos                                           6,5%          NaN
# Comics                                                     2,5%          NaN
# Otros                                                      1,3%          NaN
# NaN                                                         NaN          NaN
# NaN                                                         NaN          NaN
#
#                                                         ...       \
# Número de agentes editoriales privados                  ...
# Número de agentes editoriales públicos                  ...
# Porcentaje de la producción editorial de instit...      ...
# ISBN concedidos                                         ...
# Títulos vivos en catálogo                               ...
# Títulos editados en edición de bolsillo                 ...
# Ejemplares editados                                     ...
# Ejemplares vendidos                                     ...
# Porcentaje de títulos que son traducciones de o...      ...
# Valor de las ventas de libros en el mercado int...      ...
# Valor de las exportaciones de libros (miles de ...      ...
# Tirada media de ejemplares por título (número d...      ...
# Precio medio del libro (euros)                          ...
# Distribución por materias de la cifra global de...      ...
# Literatura                                              ...
# Texto no universitario                                  ...
# Científico/técnico                                      ...
# Infantil y juvenil                                      ...
# Divulgación general                                     ...
# Diccionarios/enciclopedias                              ...
# Ciencias Sociales y Humanidades                         ...
# Libros prácticos                                        ...
# Comics                                                  ...
# Otros                                                   ...
# NaN                                                     ...
# NaN                                                     ...
#
#                                                     Unnamed: 247  \
# Número de agentes editoriales privados                       NaN
# Número de agentes editoriales públicos                       NaN
# Porcentaje de la producción editorial de instit...           NaN
# ISBN concedidos                                              NaN
# Títulos vivos en catálogo                                    NaN
# Títulos editados en edición de bolsillo                      NaN
# Ejemplares editados                                          NaN
# Ejemplares vendidos                                          NaN
# Porcentaje de títulos que son traducciones de o...           NaN
# Valor de las ventas de libros en el mercado int...           NaN
# Valor de las exportaciones de libros (miles de ...           NaN
# Tirada media de ejemplares por título (número d...           NaN
# Precio medio del libro (euros)                               NaN
# Distribución por materias de la cifra global de...           NaN
# Literatura                                                   NaN
# Texto no universitario                                       NaN
# Científico/técnico                                           NaN
# Infantil y juvenil                                           NaN
# Divulgación general                                          NaN
# Diccionarios/enciclopedias                                   NaN
# Ciencias Sociales y Humanidades                              NaN
# Libros prácticos                                             NaN
# Comics                                                       NaN
# Otros                                                        NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                                                     Unnamed: 248  \
# Número de agentes editoriales privados                       NaN
# Número de agentes editoriales públicos                       NaN
# Porcentaje de la producción editorial de instit...           NaN
# ISBN concedidos                                              NaN
# Títulos vivos en catálogo                                    NaN
# Títulos editados en edición de bolsillo                      NaN
# Ejemplares editados                                          NaN
# Ejemplares vendidos                                          NaN
# Porcentaje de títulos que son traducciones de o...           NaN
# Valor de las ventas de libros en el mercado int...           NaN
# Valor de las exportaciones de libros (miles de ...           NaN
# Tirada media de ejemplares por título (número d...           NaN
# Precio medio del libro (euros)                               NaN
# Distribución por materias de la cifra global de...           NaN
# Literatura                                                   NaN
# Texto no universitario                                       NaN
# Científico/técnico                                           NaN
# Infantil y juvenil                                           NaN
# Divulgación general                                          NaN
# Diccionarios/enciclopedias                                   NaN
# Ciencias Sociales y Humanidades                              NaN
# Libros prácticos                                             NaN
# Comics                                                       NaN
# Otros                                                        NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                                                     Unnamed: 249  \
# Número de agentes editoriales privados                       NaN
# Número de agentes editoriales públicos                       NaN
# Porcentaje de la producción editorial de instit...           NaN
# ISBN concedidos                                              NaN
# Títulos vivos en catálogo                                    NaN
# Títulos editados en edición de bolsillo                      NaN
# Ejemplares editados                                          NaN
# Ejemplares vendidos                                          NaN
# Porcentaje de títulos que son traducciones de o...           NaN
# Valor de las ventas de libros en el mercado int...           NaN
# Valor de las exportaciones de libros (miles de ...           NaN
# Tirada media de ejemplares por título (número d...           NaN
# Precio medio del libro (euros)                               NaN
# Distribución por materias de la cifra global de...           NaN
# Literatura                                                   NaN
# Texto no universitario                                       NaN
# Científico/técnico                                           NaN
# Infantil y juvenil                                           NaN
# Divulgación general                                          NaN
# Diccionarios/enciclopedias                                   NaN
# Ciencias Sociales y Humanidades                              NaN
# Libros prácticos                                             NaN
# Comics                                                       NaN
# Otros                                                        NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                                                     Unnamed: 250  \
# Número de agentes editoriales privados                       NaN
# Número de agentes editoriales públicos                       NaN
# Porcentaje de la producción editorial de instit...           NaN
# ISBN concedidos                                              NaN
# Títulos vivos en catálogo                                    NaN
# Títulos editados en edición de bolsillo                      NaN
# Ejemplares editados                                          NaN
# Ejemplares vendidos                                          NaN
# Porcentaje de títulos que son traducciones de o...           NaN
# Valor de las ventas de libros en el mercado int...           NaN
# Valor de las exportaciones de libros (miles de ...           NaN
# Tirada media de ejemplares por título (número d...           NaN
# Precio medio del libro (euros)                               NaN
# Distribución por materias de la cifra global de...           NaN
# Literatura                                                   NaN
# Texto no universitario                                       NaN
# Científico/técnico                                           NaN
# Infantil y juvenil                                           NaN
# Divulgación general                                          NaN
# Diccionarios/enciclopedias                                   NaN
# Ciencias Sociales y Humanidades                              NaN
# Libros prácticos                                             NaN
# Comics                                                       NaN
# Otros                                                        NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                                                     Unnamed: 251  \
# Número de agentes editoriales privados                       NaN
# Número de agentes editoriales públicos                       NaN
# Porcentaje de la producción editorial de instit...           NaN
# ISBN concedidos                                              NaN
# Títulos vivos en catálogo                                    NaN
# Títulos editados en edición de bolsillo                      NaN
# Ejemplares editados                                          NaN
# Ejemplares vendidos                                          NaN
# Porcentaje de títulos que son traducciones de o...           NaN
# Valor de las ventas de libros en el mercado int...           NaN
# Valor de las exportaciones de libros (miles de ...           NaN
# Tirada media de ejemplares por título (número d...           NaN
# Precio medio del libro (euros)                               NaN
# Distribución por materias de la cifra global de...           NaN
# Literatura                                                   NaN
# Texto no universitario                                       NaN
# Científico/técnico                                           NaN
# Infantil y juvenil                                           NaN
# Divulgación general                                          NaN
# Diccionarios/enciclopedias                                   NaN
# Ciencias Sociales y Humanidades                              NaN
# Libros prácticos                                             NaN
# Comics                                                       NaN
# Otros                                                        NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                                                     Unnamed: 252  \
# Número de agentes editoriales privados                       NaN
# Número de agentes editoriales públicos                       NaN
# Porcentaje de la producción editorial de instit...           NaN
# ISBN concedidos                                              NaN
# Títulos vivos en catálogo                                    NaN
# Títulos editados en edición de bolsillo                      NaN
# Ejemplares editados                                          NaN
# Ejemplares vendidos                                          NaN
# Porcentaje de títulos que son traducciones de o...           NaN
# Valor de las ventas de libros en el mercado int...           NaN
# Valor de las exportaciones de libros (miles de ...           NaN
# Tirada media de ejemplares por título (número d...           NaN
# Precio medio del libro (euros)                               NaN
# Distribución por materias de la cifra global de...           NaN
# Literatura                                                   NaN
# Texto no universitario                                       NaN
# Científico/técnico                                           NaN
# Infantil y juvenil                                           NaN
# Divulgación general                                          NaN
# Diccionarios/enciclopedias                                   NaN
# Ciencias Sociales y Humanidades                              NaN
# Libros prácticos                                             NaN
# Comics                                                       NaN
# Otros                                                        NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                                                     Unnamed: 253  \
# Número de agentes editoriales privados                       NaN
# Número de agentes editoriales públicos                       NaN
# Porcentaje de la producción editorial de instit...           NaN
# ISBN concedidos                                              NaN
# Títulos vivos en catálogo                                    NaN
# Títulos editados en edición de bolsillo                      NaN
# Ejemplares editados                                          NaN
# Ejemplares vendidos                                          NaN
# Porcentaje de títulos que son traducciones de o...           NaN
# Valor de las ventas de libros en el mercado int...           NaN
# Valor de las exportaciones de libros (miles de ...           NaN
# Tirada media de ejemplares por título (número d...           NaN
# Precio medio del libro (euros)                               NaN
# Distribución por materias de la cifra global de...           NaN
# Literatura                                                   NaN
# Texto no universitario                                       NaN
# Científico/técnico                                           NaN
# Infantil y juvenil                                           NaN
# Divulgación general                                          NaN
# Diccionarios/enciclopedias                                   NaN
# Ciencias Sociales y Humanidades                              NaN
# Libros prácticos                                             NaN
# Comics                                                       NaN
# Otros                                                        NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                                                     Unnamed: 254  \
# Número de agentes editoriales privados                       NaN
# Número de agentes editoriales públicos                       NaN
# Porcentaje de la producción editorial de instit...           NaN
# ISBN concedidos                                              NaN
# Títulos vivos en catálogo                                    NaN
# Títulos editados en edición de bolsillo                      NaN
# Ejemplares editados                                          NaN
# Ejemplares vendidos                                          NaN
# Porcentaje de títulos que son traducciones de o...           NaN
# Valor de las ventas de libros en el mercado int...           NaN
# Valor de las exportaciones de libros (miles de ...           NaN
# Tirada media de ejemplares por título (número d...           NaN
# Precio medio del libro (euros)                               NaN
# Distribución por materias de la cifra global de...           NaN
# Literatura                                                   NaN
# Texto no universitario                                       NaN
# Científico/técnico                                           NaN
# Infantil y juvenil                                           NaN
# Divulgación general                                          NaN
# Diccionarios/enciclopedias                                   NaN
# Ciencias Sociales y Humanidades                              NaN
# Libros prácticos                                             NaN
# Comics                                                       NaN
# Otros                                                        NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                                                     Unnamed: 255  Unnamed: 256
# Número de agentes editoriales privados                       NaN           NaN
# Número de agentes editoriales públicos                       NaN           NaN
# Porcentaje de la producción editorial de instit...           NaN           NaN
# ISBN concedidos                                              NaN           NaN
# Títulos vivos en catálogo                                    NaN           NaN
# Títulos editados en edición de bolsillo                      NaN           NaN
# Ejemplares editados                                          NaN           NaN
# Ejemplares vendidos                                          NaN           NaN
# Porcentaje de títulos que son traducciones de o...           NaN           NaN
# Valor de las ventas de libros en el mercado int...           NaN           NaN
# Valor de las exportaciones de libros (miles de ...           NaN           NaN
# Tirada media de ejemplares por título (número d...           NaN           NaN
# Precio medio del libro (euros)                               NaN           NaN
# Distribución por materias de la cifra global de...           NaN           NaN
# Literatura                                                   NaN           NaN
# Texto no universitario                                       NaN           NaN
# Científico/técnico                                           NaN           NaN
# Infantil y juvenil                                           NaN           NaN
# Divulgación general                                          NaN           NaN
# Diccionarios/enciclopedias                                   NaN           NaN
# Ciencias Sociales y Humanidades                              NaN           NaN
# Libros prácticos                                             NaN           NaN
# Comics                                                       NaN           NaN
# Otros                                                        NaN           NaN
# NaN                                                          NaN           NaN
# NaN                                                          NaN           NaN
#
# [26 rows x 256 columns]

# %%
data.dropna(how='all', inplace=True)

# %%
data.dropna(how='all', inplace=True, axis=1)

# %%
data.head()
# Out:
#                                                    Año 2005 Año 2006 Año 2007  \
# Número de agentes editoriales privados                2.781    2.673    2.803
# Número de agentes editoriales públicos                  615      563      597
# Porcentaje de la producción editorial de instit...    11,5%    12,3%    11,2%
# ISBN concedidos                                      76.265   77.330   82.559
# Títulos vivos en catálogo                           325.808  346.706  369.588
#
#                                                    Año 2008 Año 2009 Año 2010  \
# Número de agentes editoriales privados                2.892    3.032    2.994
# Número de agentes editoriales públicos                  580      532      529
# Porcentaje de la producción editorial de instit...     9,8%     8,6%     8,0%
# ISBN concedidos                                     104.223  110.205  114.205
# Títulos vivos en catálogo                           393.012  414.727  439.991
#
#                                                    Año 2011 Año 2012 Año 2013
# Número de agentes editoriales privados                2.988    2.835    2.750
# Número de agentes editoriales públicos                  476      352      336
# Porcentaje de la producción editorial de instit...     7,0%     7,5%       9%
# ISBN concedidos                                     111.907  104.724   89.130
# Títulos vivos en catálogo                           464.981  490.752  524.213

# %%
data.index[7]
# Out:
# 'Ejemplares vendidos'

# %%
vtas = data.loc[_]

# %%
quitar_punto = lambda x: int(x.replace('.', ''))

# %%
vtas = vtas.map(quitar_punto)

# %%
pie = 'Fuente: La Federación de Gremios de Editores de España\nMaximiliano | @mmngreco'

# %%
horizontal = np.linspace(0, 2 * 10 ** 8, 5)

# %%
ax = vtas.plot(kind='bar', colormap='Set2')

for line in horizontal:
    plt.axhline(line, color='white')

sns.despine()

ax = plt.gca()
plt.title('Nº de Libros Vendidos', fontsize=15)
plt.text(0,-0.3, pie, fontsize=11, transform=ax.transAxes)
